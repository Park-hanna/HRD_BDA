# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib import font_manager
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %%
sns.set_style("darkgrid",rc={"font.family" : "Malgun Gothic"})

# %%
plt.rc("font", family = "malgun")
plt.rc("font", family = "Malgun Gothic")

# %%
apt_sell = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/한국부동산원_전국주택가격동향조사_월간동향_아파트_매매가격(평균매매가격)_20220430.csv", encoding= 'cp949')

# %%
pd.options.display.max_rows = 5
pd.options.display.max_columns = 20

# %%
apt_sell
# Out:
#          지 역   2012-01   2012-02   2012-03   2012-04   2012-05   2012-06  \
# 0         전국  264474.0  264035.0  263470.0  262630.0  261823.0  260425.0
# 1        수도권  365249.0  364275.0  362790.0  360918.0  359253.0  356737.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 234   제주 제주시  145425.0  150436.0  150769.0  152481.0  155972.0  155940.0
# 235  제주 서귀포시   80868.0   82283.0   83067.0   83683.0   85350.0   85383.0
#
#       2012-07   2012-08   2012-09  ...   2021-07   2021-08   2021-09  \
# 0    258959.0  257163.0  255680.0  ...  491728.0  498221.0  504121.0
# 1    354214.0  350990.0  348174.0  ...  721261.0  731999.0  741851.0
# ..        ...       ...       ...  ...       ...       ...       ...
# 234  155978.0  155987.0  155944.0  ...  333712.0  345366.0  352627.0
# 235   85383.0   85317.0   85317.0  ...  230542.0  232347.0  233847.0
#
#       2021-10   2021-11   2021-12   2022-01   2022-02   2022-03   2022-04
# ...

# %%
apt_sell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Columns: 125 entries, 지 역 to 2022-04
# dtypes: float64(124), object(1)
# memory usage: 230.6+ KB

# %%
apt_lease = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/한국부동산원_전국주택가격동향조사_월간동향_아파트_전세가격(평균단위전세가격)_20210731.csv", encoding= 'cp949')

# %%
apt_lease
# Out:
#           지역  2012-01  2012-02  2012-03  2012-04  2012-05  2012-06  2012-07  \
# 0         전국   1880.0   1882.0   1883.0   1882.0   1880.0   1877.0   1870.0
# 1        수도권   2344.0   2346.0   2343.0   2337.0   2330.0   2323.0   2312.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 234   제주 제주시   1304.0   1341.0   1344.0   1351.0   1400.0   1399.0   1399.0
# 235  제주 서귀포시    846.0    862.0    874.0    876.0    895.0    896.0    896.0
#
#      2012-08  2012-09  ...  2020-10  2020-11  2020-12  2021-01  2021-02  \
# 0     1867.0   1873.0  ...   3072.0   3109.0   3162.0   3201.0   3234.0
# 1     2306.0   2315.0  ...   4167.0   4214.0   4273.0   4316.0   4357.0
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 234   1400.0   1400.0  ...   2735.0   2735.0   2741.0   2754.0   2782.0
# 235    895.0    895.0  ...   2255.0   2255.0   2259.0   2267.0   2274.0
#
#      2021-03  2021-04  2021-05  2021-06  2021-07
# ...

# %%
apt_lease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Columns: 116 entries, 지역 to 2021-07
# dtypes: float64(115), object(1)
# memory usage: 214.0+ KB

# %%
apt_lease.to_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/lease.csv")

# %% [markdown]
# # 데이터 파일
# - 주택 도시 보증 공사 _ 전국 신규 민간 아파트 분양 가격 동향
# - 한국 부동산원 _ 전국 주택 가격 동향 조사 _ 월간 동향 아파트 _ 매매가격 (평균매매가격) _20220430
# - 한국 부동산원 _ 전국주택가격동향 조사 _ 월간 동향 _ 아파트 _ 전세가격 (평균단위전세가격) _ 20210730
# - 주민등록 인구 기타 현황(세대원수별 세대수) : 2015년 10월 ~ 2022년 7월까지 <br>
#  => 201510_201709_ 주민등록인구기타현황(세대원수별 세대수) <br>
#  => 201710_201909_ 주민등록인구기타현황(세대원수별 세대수) <br>
#  => 201910_202109_ 주민등록인구기타현황(세대원수별 세대수) <br>
#  => 202110_202209_ 주민등록인구기타현황(세대원수별 세대수) <br>
#  **만약 다운로드 받은 데이터가 엑셀 파일이면 인코딩 설정 cp949 또는 euc-kr 로 인코딩 데이터를 데이터 프레임 형식으로 로드

# %%
apt = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/apt_div.csv")

# %%
apt
# Out:
#       Unnamed: 0 지역명    연도   월  분양가격(m2)   평당분양가격              전용면적
# 0              0  서울  2015  10    5841.0  19275.3              모든면적
# 1              1  서울  2015  10    5652.0  18651.6            60제곱미터
# ...          ...  ..   ...  ..       ...      ...               ...
# 6288        6288  제주  2021  11       NaN      NaN   85제곱미터~ 102제곱미터
# 6289        6289  제주  2021  11       NaN      NaN          102제곱미터~
#
# [6290 rows x 7 columns]

# %%
apt_sell = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/한국부동산원_전국주택가격동향조사_월간동향_아파트_매매가격(평균매매가격)_20220430.csv", encoding='cp949')

# %%
apt_sell
# Out:
#          지 역   2012-01   2012-02   2012-03   2012-04   2012-05   2012-06  \
# 0         전국  264474.0  264035.0  263470.0  262630.0  261823.0  260425.0
# 1        수도권  365249.0  364275.0  362790.0  360918.0  359253.0  356737.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 234   제주 제주시  145425.0  150436.0  150769.0  152481.0  155972.0  155940.0
# 235  제주 서귀포시   80868.0   82283.0   83067.0   83683.0   85350.0   85383.0
#
#       2012-07   2012-08   2012-09  ...   2021-07   2021-08   2021-09  \
# 0    258959.0  257163.0  255680.0  ...  491728.0  498221.0  504121.0
# 1    354214.0  350990.0  348174.0  ...  721261.0  731999.0  741851.0
# ..        ...       ...       ...  ...       ...       ...       ...
# 234  155978.0  155987.0  155944.0  ...  333712.0  345366.0  352627.0
# 235   85383.0   85317.0   85317.0  ...  230542.0  232347.0  233847.0
#
#       2021-10   2021-11   2021-12   2022-01   2022-02   2022-03   2022-04
# ...

# %%
apt_lease
# Out:
#           지역  2012-01  2012-02  2012-03  2012-04  2012-05  2012-06  2012-07  \
# 0         전국   1880.0   1882.0   1883.0   1882.0   1880.0   1877.0   1870.0
# 1        수도권   2344.0   2346.0   2343.0   2337.0   2330.0   2323.0   2312.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 234   제주 제주시   1304.0   1341.0   1344.0   1351.0   1400.0   1399.0   1399.0
# 235  제주 서귀포시    846.0    862.0    874.0    876.0    895.0    896.0    896.0
#
#      2012-08  2012-09  ...  2020-10  2020-11  2020-12  2021-01  2021-02  \
# 0     1867.0   1873.0  ...   3072.0   3109.0   3162.0   3201.0   3234.0
# 1     2306.0   2315.0  ...   4167.0   4214.0   4273.0   4316.0   4357.0
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 234   1400.0   1400.0  ...   2735.0   2735.0   2741.0   2754.0   2782.0
# 235    895.0    895.0  ...   2255.0   2255.0   2259.0   2267.0   2274.0
#
#      2021-03  2021-04  2021-05  2021-06  2021-07
# ...

# %%
apt_sell_year = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/apt_sell_year2.csv")

# %%
apt_sell_year
# Out:
#          지 역           2012           2013           2014           2015  \
# 0         전국  258998.666667  249156.833333  254840.916667  268960.250000
# 1        수도권  354289.833333  334043.833333  339409.583333  357872.416667
# ..       ...            ...            ...            ...            ...
# 234   제주 제주시  153718.833333  153155.583333  161831.583333  206100.250000
# 235  제주 서귀포시   84404.250000   85437.833333   87726.750000  122865.166667
#
#               2016           2017           2018           2019           2020
# 0    281272.333333  288256.833333  321295.916667  346602.000000  379655.666667
# 1    375368.750000  388138.333333  445578.333333  491286.250000  545120.666667
# ..             ...            ...            ...            ...            ...
# 234  259236.833333  271233.416667  313133.750000  315408.000000  304452.166667
# 235  161203.583333  183953.166667  226759.416667  239597.583333  224365.083333
#
# [236 rows x 10 columns]

# %%
apt_sell_y_sel = apt_sell_year.loc[[0,1,2,3,4,5,6,7,40,96,106,126,135,141,147,153,154,162,175,189,198,205,219,233]]

# %%
apt_sell_y_sel2 = apt_sell_y_sel.set_index("지 역")

# %%
apt_sell_y_sel2
# Out:
#               2012           2013           2014           2015  \
# 지 역
# 전국   258998.666667  249156.833333  254840.916667  268960.250000
# 수도권  354289.833333  334043.833333  339409.583333  357872.416667
# ..             ...            ...            ...            ...
# 경남   180959.166667  177563.916667  180636.000000  189345.666667
# 제주   142525.583333  142287.666667  149938.416667  191835.333333
#
#               2016           2017           2018           2019           2020
# 지 역
# 전국   281272.333333  288256.833333  321295.916667  346602.000000  379655.666667
# 수도권  375368.750000  388138.333333  445578.333333  491286.250000  545120.666667
# ..             ...            ...            ...            ...            ...
# 경남   193759.416667  189248.500000  177627.416667  175507.916667  179506.250000
# 제주   241980.666667  254657.250000  293969.000000  297279.083333  285043.833333
#
# [24 rows x 9 columns]

# %%
apt_lease_year = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/apt_lease_year2.csv")

# %%
apt_lease_year
# Out:
#           지역         2012         2013         2014         2015         2016  \
# 0         전국  1879.750000  1956.416667  2122.416667  2334.166667  2533.166667
# 1        수도권  2330.083333  2427.000000  2677.833333  2998.250000  3305.500000
# ..       ...          ...          ...          ...          ...          ...
# 234   제주 제주시  1377.750000  1417.666667  1565.666667  1938.250000  2276.333333
# 235  제주 서귀포시   885.250000   901.833333   944.500000  1344.750000  1776.083333
#
#             2017         2018         2019         2020
# 0    2602.500000  2824.333333  2809.500000  3009.583333
# 1    3424.750000  3775.166667  3746.583333  4075.416667
# ..           ...          ...          ...          ...
# 234  2370.166667  2805.000000  2756.916667  2745.083333
# 235  2021.083333  2382.583333  2370.750000  2266.250000
#
# [236 rows x 10 columns]

# %%
apt_lease_y_sel = apt_lease_year.loc[[0,1,2,3,4,5,6,7,40,96,106,126,135,141,147,153,154,162,175,189,198,205,219,233]]

# %%
apt_lease_y_sel
# Out:
#       지역         2012         2013         2014         2015         2016  \
# 0     전국  1879.750000  1956.416667  2122.416667  2334.166667  2533.166667
# 1    수도권  2330.083333  2427.000000  2677.833333  2998.250000  3305.500000
# ..   ...          ...          ...          ...          ...          ...
# 219   경남  1534.333333  1576.583333  1645.000000  1731.416667  1804.083333
# 233   제주  1298.250000  1335.083333  1465.750000  1836.666667  2189.000000
#
#             2017         2018         2019         2020
# 0    2602.500000  2824.333333  2809.500000  3009.583333
# 1    3424.750000  3775.166667  3746.583333  4075.416667
# ..           ...          ...          ...          ...
# 219  1791.833333  1705.000000  1682.500000  1692.750000
# 233  2303.416667  2711.416667  2664.500000  2629.000000
#
# [24 rows x 10 columns]

# %%
apt_lease_y_sel2 = apt_lease_y_sel.set_index("지역")
apt_lease_y_sel2
# Out:
#             2012         2013         2014         2015         2016  \
# 지역
# 전국   1879.750000  1956.416667  2122.416667  2334.166667  2533.166667
# 수도권  2330.083333  2427.000000  2677.833333  2998.250000  3305.500000
# ..           ...          ...          ...          ...          ...
# 경남   1534.333333  1576.583333  1645.000000  1731.416667  1804.083333
# 제주   1298.250000  1335.083333  1465.750000  1836.666667  2189.000000
#
#             2017         2018         2019         2020
# 지역
# 전국   2602.500000  2824.333333  2809.500000  3009.583333
# 수도권  3424.750000  3775.166667  3746.583333  4075.416667
# ..           ...          ...          ...          ...
# 경남   1791.833333  1705.000000  1682.500000  1692.750000
# 제주   2303.416667  2711.416667  2664.500000  2629.000000
#
# [24 rows x 9 columns]

# %%
people1 = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/201201_201412_주민등록인구기타현황(세대원수별 세대수).csv", encoding='cp949')
people2 = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/201501_201712_주민등록인구기타현황(세대원수별 세대수).csv", encoding='cp949')
people3 = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/201801_202012_주민등록인구기타현황(세대원수별 세대수).csv", encoding='cp949')
people4 = pd.read_csv("C:/Users/ParkHanna/Desktop/HRD/BigData/data/202101_202207_주민등록인구기타현황(세대원수별 세대수).csv", encoding='cp949')

# %%
people1
# Out:
#                      행정구역 2012년01월_전체세대 2012년01월_1인세대 2012년01월_2인세대  \
# 0        전국  (1000000000)    20,038,189     6,663,066     3,920,741
# 1     서울특별시  (1100000000)     4,191,988     1,508,631       786,256
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,287,427       411,138       260,492
# 17  제주특별자치도  (5000000000)       228,078        83,367        41,746
#
#    2012년01월_3인세대 2012년01월_4인세대 2012년01월_5인세대 2012년01월_6인세대 2012년01월_7인세대  \
# 0      3,702,614     4,193,849     1,187,645       277,771        66,953
# 1        775,728       853,857       208,718        44,936        10,069
# ..           ...           ...           ...           ...           ...
# 16       235,757       271,935        81,699        19,685         4,745
# 17        37,947        40,036        17,948         4,972         1,480
#
#    2012년01월_8인세대  ... 2014년12월_1인세대 2014년12월_2인세대 2014년12월_3인세대 2014년12월_4인세대  \
# ...

# %%
people2
# Out:
#                      행정구역 2015년01월_전체세대 2015년01월_1인세대 2015년01월_2인세대  \
# 0        전국  (1000000000)    20,740,958     7,055,725     4,308,710
# 1     서울특별시  (1100000000)     4,196,435     1,527,227       827,834
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,345,576       446,761       290,748
# 17  제주특별자치도  (5000000000)       247,053        91,959        48,839
#
#    2015년01월_3인세대 2015년01월_4인세대 2015년01월_5인세대 2015년01월_6인세대 2015년01월_7인세대  \
# 0      3,843,262     4,064,349     1,123,310       258,062        62,500
# 1        783,708       805,973       194,415        43,005        10,182
# ..           ...           ...           ...           ...           ...
# 16       245,842       262,997        76,051        17,245         4,181
# 17        40,864        40,925        17,833         4,737         1,358
#
#    2015년01월_8인세대  ... 2017년12월_1인세대 2017년12월_2인세대 2017년12월_3인세대 2017년12월_4인세대  \
# ...

# %%
people3
# Out:
#                      행정구역 2018년01월_전체세대 2018년01월_1인세대 2018년01월_2인세대  \
# 0        전국  (1000000000)    21,662,900     7,749,175     4,751,669
# 1     서울특별시  (1100000000)     4,224,387     1,614,420       870,433
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,407,283       489,242       323,799
# 17  제주특별자치도  (5000000000)       278,955       109,702        58,170
#
#    2018년01월_3인세대 2018년01월_4인세대 2018년01월_5인세대 2018년01월_6인세대 2018년01월_7인세대  \
# 0      3,960,950     3,849,392     1,039,518       232,324        56,447
# 1        776,034       733,217       176,204        39,788        10,023
# ..           ...           ...           ...           ...           ...
# 16       255,253       249,786        69,155        15,091         3,506
# 17        45,393        41,828        17,594         4,528         1,246
#
#    2018년01월_8인세대  ... 2020년12월_1인세대 2020년12월_2인세대 2020년12월_3인세대 2020년12월_4인세대  \
# ...

# %%
people4
# Out:
#                      행정구역 2021년01월_전체세대 2021년01월_1인세대 2021년01월_2인세대  \
# 0        전국  (1000000000)    23,137,172     9,107,212     5,423,558
# 1     서울특별시  (1100000000)     4,421,022     1,864,183       962,236
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,487,083       568,943       368,325
# 17  제주특별자치도  (5000000000)       302,473       126,206        67,616
#
#    2021년01월_3인세대 2021년01월_4인세대 2021년01월_5인세대 2021년01월_6인세대 2021년01월_7인세대  \
# 0      4,009,019     3,501,499       866,468       173,880        39,384
# 1        760,769       646,848       145,500        30,926         7,406
# ..           ...           ...           ...           ...           ...
# 16       257,287       223,685        55,475        10,327         2,140
# 17        48,088        40,649        15,175         3,583           867
#
#    2021년01월_8인세대  ... 2022년07월_1인세대 2022년07월_2인세대 2022년07월_3인세대 2022년07월_4인세대  \
# ...

# %%
people1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 397 entries, 행정구역 to 2014년12월_10인세대
# dtypes: object(397)
# memory usage: 56.0+ KB

# %%
people2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 397 entries, 행정구역 to 2017년12월_10인세대
# dtypes: object(397)
# memory usage: 56.0+ KB

# %%
people3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 397 entries, 행정구역 to 2020년12월_10인세대
# dtypes: object(397)
# memory usage: 56.0+ KB

# %%
people4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 210 entries, 행정구역 to 2022년07월_10인세대
# dtypes: object(210)
# memory usage: 29.7+ KB

# %%
people1.describe()
# Out:
#                     행정구역 2012년01월_전체세대 2012년01월_1인세대 2012년01월_2인세대  \
# count                 18            17            17            17
# unique                18            17            17            17
# top     전국  (1000000000)    20,038,189     6,663,066     3,920,741
# freq                   1             1             1             1
#
#        2012년01월_3인세대 2012년01월_4인세대 2012년01월_5인세대 2012년01월_6인세대 2012년01월_7인세대  \
# count             17            17            17            17            17
# unique            17            17            17            17            17
# top        3,702,614     4,193,849     1,187,645       277,771        66,953
# freq               1             1             1             1             1
#
#        2012년01월_8인세대  ... 2014년12월_1인세대 2014년12월_2인세대 2014년12월_3인세대  \
# count             17  ...            18            18            18
# unique            16  ...            18            18            18
# ...

# %%
people2.describe()
# Out:
#                     행정구역 2015년01월_전체세대 2015년01월_1인세대 2015년01월_2인세대  \
# count                 18            18            18            18
# unique                18            18            18            18
# top     전국  (1000000000)    20,740,958     7,055,725     4,308,710
# freq                   1             1             1             1
#
#        2015년01월_3인세대 2015년01월_4인세대 2015년01월_5인세대 2015년01월_6인세대 2015년01월_7인세대  \
# count             18            18            18            18            18
# unique            18            18            18            18            18
# top        3,843,262     4,064,349     1,123,310       258,062        62,500
# freq               1             1             1             1             1
#
#        2015년01월_8인세대  ... 2017년12월_1인세대 2017년12월_2인세대 2017년12월_3인세대  \
# count             18  ...            18            18            18
# unique            18  ...            18            18            18
# ...

# %%
people3.describe()
# Out:
#                     행정구역 2018년01월_전체세대 2018년01월_1인세대 2018년01월_2인세대  \
# count                 18            18            18            18
# unique                18            18            18            18
# top     전국  (1000000000)    21,662,900     7,749,175     4,751,669
# freq                   1             1             1             1
#
#        2018년01월_3인세대 2018년01월_4인세대 2018년01월_5인세대 2018년01월_6인세대 2018년01월_7인세대  \
# count             18            18            18            18            18
# unique            18            18            18            18            18
# top        3,960,950     3,849,392     1,039,518       232,324        56,447
# freq               1             1             1             1             1
#
#        2018년01월_8인세대  ... 2020년12월_1인세대 2020년12월_2인세대 2020년12월_3인세대  \
# count             18  ...            18            18            18
# unique            18  ...            18            18            18
# ...

# %%
people4.describe()
# Out:
#                     행정구역 2021년01월_전체세대 2021년01월_1인세대 2021년01월_2인세대  \
# count                 18            18            18            18
# unique                18            18            18            18
# top     전국  (1000000000)    23,137,172     9,107,212     5,423,558
# freq                   1             1             1             1
#
#        2021년01월_3인세대 2021년01월_4인세대 2021년01월_5인세대 2021년01월_6인세대 2021년01월_7인세대  \
# count             18            18            18            18            18
# unique            18            18            18            18            18
# top        4,009,019     3,501,499       866,468       173,880        39,384
# freq               1             1             1             1             1
#
#        2021년01월_8인세대  ... 2022년07월_1인세대 2022년07월_2인세대 2022년07월_3인세대  \
# count             18  ...            18            18            18
# unique            18  ...            18            18            18
# ...

# %%
people1.isnull().sum()
# Out:
# 행정구역              0
# 2012년01월_전체세대     1
#                  ..
# 2014년12월_9인세대     0
# 2014년12월_10인세대    0
# Length: 397, dtype: int64

# %%
people2.isnull().sum()
# Out:
# 행정구역              0
# 2015년01월_전체세대     0
#                  ..
# 2017년12월_9인세대     0
# 2017년12월_10인세대    0
# Length: 397, dtype: int64

# %%
people3.isnull().sum()
# Out:
# 행정구역              0
# 2018년01월_전체세대     0
#                  ..
# 2020년12월_9인세대     0
# 2020년12월_10인세대    0
# Length: 397, dtype: int64

# %%
people4.isnull().sum()
# Out:
# 행정구역              0
# 2021년01월_전체세대     0
#                  ..
# 2022년07월_9인세대     0
# 2022년07월_10인세대    0
# Length: 210, dtype: int64

# %% [markdown]
# # EDA - 1 아파트 매매 데이터 시각화

# %%
plt.figure(figsize=(16,7))
sns.barplot(data=apt_sell_year, x= '지 역', y='2012')
# Out:
# <Axes: xlabel='지 역', ylabel='2012'>

# %%
apt_sell_y_sel2
# Out:
#               2012           2013           2014           2015  \
# 지 역
# 전국   258998.666667  249156.833333  254840.916667  268960.250000
# 수도권  354289.833333  334043.833333  339409.583333  357872.416667
# ..             ...            ...            ...            ...
# 경남   180959.166667  177563.916667  180636.000000  189345.666667
# 제주   142525.583333  142287.666667  149938.416667  191835.333333
#
#               2016           2017           2018           2019           2020
# 지 역
# 전국   281272.333333  288256.833333  321295.916667  346602.000000  379655.666667
# 수도권  375368.750000  388138.333333  445578.333333  491286.250000  545120.666667
# ..             ...            ...            ...            ...            ...
# 경남   193759.416667  189248.500000  177627.416667  175507.916667  179506.250000
# 제주   241980.666667  254657.250000  293969.000000  297279.083333  285043.833333
#
# [24 rows x 9 columns]

# %%
apt_lease_y_sel2
# Out:
#             2012         2013         2014         2015         2016  \
# 지역
# 전국   1879.750000  1956.416667  2122.416667  2334.166667  2533.166667
# 수도권  2330.083333  2427.000000  2677.833333  2998.250000  3305.500000
# ..           ...          ...          ...          ...          ...
# 경남   1534.333333  1576.583333  1645.000000  1731.416667  1804.083333
# 제주   1298.250000  1335.083333  1465.750000  1836.666667  2189.000000
#
#             2017         2018         2019         2020
# 지역
# 전국   2602.500000  2824.333333  2809.500000  3009.583333
# 수도권  3424.750000  3775.166667  3746.583333  4075.416667
# ..           ...          ...          ...          ...
# 경남   1791.833333  1705.000000  1682.500000  1692.750000
# 제주   2303.416667  2711.416667  2664.500000  2629.000000
#
# [24 rows x 9 columns]

# %%
p = pd.concat([apt_sell_y_sel2, apt_lease_y_sel2])

# %%
p
# Out:
#               2012           2013           2014           2015  \
# 전국   258998.666667  249156.833333  254840.916667  268960.250000
# 수도권  354289.833333  334043.833333  339409.583333  357872.416667
# ..             ...            ...            ...            ...
# 경남     1534.333333    1576.583333    1645.000000    1731.416667
# 제주     1298.250000    1335.083333    1465.750000    1836.666667
#
#               2016           2017           2018       2019           2020
# 전국   281272.333333  288256.833333  321295.916667  346602.00  379655.666667
# 수도권  375368.750000  388138.333333  445578.333333  491286.25  545120.666667
# ..             ...            ...            ...        ...            ...
# 경남     1804.083333    1791.833333    1705.000000    1682.50    1692.750000
# 제주     2189.000000    2303.416667    2711.416667    2664.50    2629.000000
#
# [48 rows x 9 columns]

# %%
p2 = pd.merge(apt_lease_y_sel2, apt_lease_y_sel2, on="지역")

# %%
p2
# Out:
#           2012_x       2013_x       2014_x       2015_x       2016_x  \
# 지역
# 전국   1879.750000  1956.416667  2122.416667  2334.166667  2533.166667
# 수도권  2330.083333  2427.000000  2677.833333  2998.250000  3305.500000
# ..           ...          ...          ...          ...          ...
# 경남   1534.333333  1576.583333  1645.000000  1731.416667  1804.083333
# 제주   1298.250000  1335.083333  1465.750000  1836.666667  2189.000000
#
#           2017_x       2018_x       2019_x       2020_x       2012_y  \
# 지역
# 전국   2602.500000  2824.333333  2809.500000  3009.583333  1879.750000
# 수도권  3424.750000  3775.166667  3746.583333  4075.416667  2330.083333
# ..           ...          ...          ...          ...          ...
# 경남   1791.833333  1705.000000  1682.500000  1692.750000  1534.333333
# 제주   2303.416667  2711.416667  2664.500000  2629.000000  1298.250000
#
#           2013_y       2014_y       2015_y       2016_y       2017_y  \
# 지역
# ...

# %%
p = pd.merge(people1, people2, on="행정구역")

# %%
p
# Out:
#                      행정구역 2012년01월_전체세대 2012년01월_1인세대 2012년01월_2인세대  \
# 0        전국  (1000000000)    20,038,189     6,663,066     3,920,741
# 1     서울특별시  (1100000000)     4,191,988     1,508,631       786,256
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,287,427       411,138       260,492
# 17  제주특별자치도  (5000000000)       228,078        83,367        41,746
#
#    2012년01월_3인세대 2012년01월_4인세대 2012년01월_5인세대 2012년01월_6인세대 2012년01월_7인세대  \
# 0      3,702,614     4,193,849     1,187,645       277,771        66,953
# 1        775,728       853,857       208,718        44,936        10,069
# ..           ...           ...           ...           ...           ...
# 16       235,757       271,935        81,699        19,685         4,745
# 17        37,947        40,036        17,948         4,972         1,480
#
#    2012년01월_8인세대  ... 2017년12월_1인세대 2017년12월_2인세대 2017년12월_3인세대 2017년12월_4인세대  \
# ...

# %%
p = pd.merge(p, people3, on="행정구역")

# %%
p
# Out:
#                      행정구역 2012년01월_전체세대 2012년01월_1인세대 2012년01월_2인세대  \
# 0        전국  (1000000000)    20,038,189     6,663,066     3,920,741
# 1     서울특별시  (1100000000)     4,191,988     1,508,631       786,256
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,287,427       411,138       260,492
# 17  제주특별자치도  (5000000000)       228,078        83,367        41,746
#
#    2012년01월_3인세대 2012년01월_4인세대 2012년01월_5인세대 2012년01월_6인세대 2012년01월_7인세대  \
# 0      3,702,614     4,193,849     1,187,645       277,771        66,953
# 1        775,728       853,857       208,718        44,936        10,069
# ..           ...           ...           ...           ...           ...
# 16       235,757       271,935        81,699        19,685         4,745
# 17        37,947        40,036        17,948         4,972         1,480
#
#    2012년01월_8인세대  ... 2020년12월_1인세대 2020년12월_2인세대 2020년12월_3인세대 2020년12월_4인세대  \
# ...

# %%
p = pd.merge(p,people4, on="행정구역")

# %%
people = p

# %%
people
# Out:
#                      행정구역 2012년01월_전체세대 2012년01월_1인세대 2012년01월_2인세대  \
# 0        전국  (1000000000)    20,038,189     6,663,066     3,920,741
# 1     서울특별시  (1100000000)     4,191,988     1,508,631       786,256
# ..                    ...           ...           ...           ...
# 16     경상남도  (4800000000)     1,287,427       411,138       260,492
# 17  제주특별자치도  (5000000000)       228,078        83,367        41,746
#
#    2012년01월_3인세대 2012년01월_4인세대 2012년01월_5인세대 2012년01월_6인세대 2012년01월_7인세대  \
# 0      3,702,614     4,193,849     1,187,645       277,771        66,953
# 1        775,728       853,857       208,718        44,936        10,069
# ..           ...           ...           ...           ...           ...
# 16       235,757       271,935        81,699        19,685         4,745
# 17        37,947        40,036        17,948         4,972         1,480
#
#    2012년01월_8인세대  ... 2022년07월_1인세대 2022년07월_2인세대 2022년07월_3인세대 2022년07월_4인세대  \
# ...
